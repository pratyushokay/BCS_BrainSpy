# %%
import nibabel as nib
import numpy as np
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder_path = '/content/drive/MyDrive/BCSpratyush'


nii_files = [f for f in os.listdir(folder_path) if f.endswith('.nii') or f.endswith('.nii.gz')]


for file in nii_files:
    file_path = os.path.join(folder_path, file)
    img = nib.load(file_path)
    print(f"Loaded {file} with shape {img.shape}")
# Out:
# Loaded sub-65304_ses-1_acq-t1csmp2ragesag06mmUNIDEN_T1w.nii with shape (256, 384, 384)
# Loaded sub-66287_ses-1_acq-t1csmp2ragesag06mmUNIDEN_T1w.nii with shape (256, 362, 384)
# Loaded sub-68576_ses-2_acq-t1csmp2ragesag06mmUNIDEN_T1w.nii with shape (256, 362, 384)
# Loaded sub-65304_ses-2_acq-t1csmp2ragesag06mmUNIDEN_T1w.nii with shape (256, 384, 384)
# Loaded sub-62038_ses-1_acq-t1csmp2ragesag06mmUNIDEN_T1w.nii with shape (256, 362, 384)

# %%
# !pip install SimpleITK
import SimpleITK as sitk
import os

# Paths
nii_folder = '/content/drive/MyDrive/BCSpratyush'
dicom_output_root = '/content/drive/MyDrive/BCSpratyush2'
os.makedirs(dicom_output_root, exist_ok=True)

# List of NIfTI files
nii_files = [f for f in os.listdir(nii_folder) if f.endswith('.nii') or f.endswith('.nii.gz')]

for nii_file in nii_files:
    # Loading NIfTI image
    nii_path = os.path.join(nii_folder, nii_file)
    image = sitk.ReadImage(nii_path)

    # Preparing output folder
    patient_id = os.path.splitext(nii_file)[0].replace('.nii', '').replace('.gz', '')
    dicom_folder = os.path.join(dicom_output_root, patient_id)
    os.makedirs(dicom_folder, exist_ok=True)

    print(f"Converting {nii_file} -> {dicom_folder} ...")

    # Getting number of slices (depth)
    num_slices = image.GetDepth()

    # Writing each slice as a DICOM file
    for i in range(num_slices):
        slice_img = image[:, :, i]
        slice_img = sitk.Cast(slice_img, sitk.sitkInt16)

        # Fixing the direction matrix to avoid DICOM errors
        slice_img.SetDirection([1.0, 0.0,
                        0.0, 1.0])


        slice_path = os.path.join(dicom_folder, f"slice_{i:03d}.dcm")

        # Adding basic DICOM metadata
        slice_img.SetMetaData("0008|0060", "MR")               # Modality
        slice_img.SetMetaData("0010|0010", "Test^Subject")     # Patient Name
        slice_img.SetMetaData("0010|0020", "123456")           # Patient ID
        slice_img.SetMetaData("0008|103e", f"Slice {i}")       # Series Description

        sitk.WriteImage(slice_img, slice_path)

    print(f"Saved {num_slices} slices to {dicom_folder}")
# Out:
# Requirement already satisfied: SimpleITK in /usr/local/lib/python3.11/dist-packages (2.5.0)
# Converting sub-65304_ses-1_acq-t1csmp2ragesag06mmUNIDEN_T1w.nii -> /content/drive/MyDrive/BCSpratyush2/sub-65304_ses-1_acq-t1csmp2ragesag06mmUNIDEN_T1w ...
# Saved 384 slices to /content/drive/MyDrive/BCSpratyush2/sub-65304_ses-1_acq-t1csmp2ragesag06mmUNIDEN_T1w
# Converting sub-66287_ses-1_acq-t1csmp2ragesag06mmUNIDEN_T1w.nii -> /content/drive/MyDrive/BCSpratyush2/sub-66287_ses-1_acq-t1csmp2ragesag06mmUNIDEN_T1w ...
# Saved 384 slices to /content/drive/MyDrive/BCSpratyush2/sub-66287_ses-1_acq-t1csmp2ragesag06mmUNIDEN_T1w
# Converting sub-68576_ses-2_acq-t1csmp2ragesag06mmUNIDEN_T1w.nii -> /content/drive/MyDrive/BCSpratyush2/sub-68576_ses-2_acq-t1csmp2ragesag06mmUNIDEN_T1w ...
# Saved 384 slices to /content/drive/MyDrive/BCSpratyush2/sub-68576_ses-2_acq-t1csmp2ragesag06mmUNIDEN_T1w
# Converting sub-65304_ses-2_acq-t1csmp2ragesag06mmUNIDEN_T1w.nii -> /content/drive/MyDrive/BCSpratyush2/sub-65304_ses-2_acq-t1csmp2ragesag06mmUNIDEN_T1w ...
# Saved 384 slices to /content/drive/MyDrive/BCSpratyush2/sub-65304_ses-2_acq-t1csmp2ragesag06mmUNIDEN_T1w
# Converting sub-62038_ses-1_acq-t1csmp2ragesag06mmUNIDEN_T1w.nii -> /content/drive/MyDrive/BCSpratyush2/sub-62038_ses-1_acq-t1csmp2ragesag06mmUNIDEN_T1w ...
# Saved 384 slices to /content/drive/MyDrive/BCSpratyush2/sub-62038_ses-1_acq-t1csmp2ragesag06mmUNIDEN_T1w

# %%
# !pip install SimpleITK
import SimpleITK as sitk
import os

# Paths
nii_folder = '/content/drive/MyDrive/BCSpratyush'
dicom_output_root = '/content/drive/MyDrive/BCSpratyush2'
os.makedirs(dicom_output_root, exist_ok=True)

# List of NIfTI files
nii_files = [f for f in os.listdir(nii_folder) if f.endswith('.nii') or f.endswith('.nii.gz')]

for nii_file in nii_files:
    # Loading NIfTI image
    nii_path = os.path.join(nii_folder, nii_file)
    image = sitk.ReadImage(nii_path)

    # Preparing output folder
    patient_id = os.path.splitext(nii_file)[0].replace('.nii', '').replace('.gz', '')
    dicom_folder = os.path.join(dicom_output_root, patient_id)
    os.makedirs(dicom_folder, exist_ok=True)

    print(f"Converting {nii_file} -> {dicom_folder} ...")

    # Getting number of slices (depth)
    num_slices = image.GetDepth()

    # Writing each slice as a DICOM file
    for i in range(num_slices):
        slice_img = image[:, :, i]
        slice_img = sitk.Cast(slice_img, sitk.sitkInt16)

        # Fixing the direction matrix to avoid DICOM errors
        slice_img.SetDirection([1.0, 0.0,
                        0.0, 1.0])


        slice_path = os.path.join(dicom_folder, f"slice_{i:03d}.dcm")

        # Adding basic DICOM metadata
        slice_img.SetMetaData("0008|0060", "MR")               # Modality
        slice_img.SetMetaData("0010|0010", "Test^Subject")     # Patient Name
        slice_img.SetMetaData("0010|0020", "123456")           # Patient ID
        slice_img.SetMetaData("0008|103e", f"Slice {i}")       # Series Description

        sitk.WriteImage(slice_img, slice_path)

    print(f"Saved {num_slices} slices to {dicom_folder}")
# Out:
# Requirement already satisfied: SimpleITK in /usr/local/lib/python3.11/dist-packages (2.5.0)
# Converting sub-65304_ses-1_acq-t1csmp2ragesag06mmUNIDEN_T1w.nii -> /content/drive/MyDrive/BCSpratyush2/sub-65304_ses-1_acq-t1csmp2ragesag06mmUNIDEN_T1w ...
# Saved 384 slices to /content/drive/MyDrive/BCSpratyush2/sub-65304_ses-1_acq-t1csmp2ragesag06mmUNIDEN_T1w
# Converting sub-66287_ses-1_acq-t1csmp2ragesag06mmUNIDEN_T1w.nii -> /content/drive/MyDrive/BCSpratyush2/sub-66287_ses-1_acq-t1csmp2ragesag06mmUNIDEN_T1w ...
# Saved 384 slices to /content/drive/MyDrive/BCSpratyush2/sub-66287_ses-1_acq-t1csmp2ragesag06mmUNIDEN_T1w
# Converting sub-68576_ses-2_acq-t1csmp2ragesag06mmUNIDEN_T1w.nii -> /content/drive/MyDrive/BCSpratyush2/sub-68576_ses-2_acq-t1csmp2ragesag06mmUNIDEN_T1w ...
# Saved 384 slices to /content/drive/MyDrive/BCSpratyush2/sub-68576_ses-2_acq-t1csmp2ragesag06mmUNIDEN_T1w
# Converting sub-65304_ses-2_acq-t1csmp2ragesag06mmUNIDEN_T1w.nii -> /content/drive/MyDrive/BCSpratyush2/sub-65304_ses-2_acq-t1csmp2ragesag06mmUNIDEN_T1w ...
# Saved 384 slices to /content/drive/MyDrive/BCSpratyush2/sub-65304_ses-2_acq-t1csmp2ragesag06mmUNIDEN_T1w
# Converting sub-62038_ses-1_acq-t1csmp2ragesag06mmUNIDEN_T1w.nii -> /content/drive/MyDrive/BCSpratyush2/sub-62038_ses-1_acq-t1csmp2ragesag06mmUNIDEN_T1w ...
# Saved 384 slices to /content/drive/MyDrive/BCSpratyush2/sub-62038_ses-1_acq-t1csmp2ragesag06mmUNIDEN_T1w

# %%
#For NIfTI:
nii_folder = '/content/drive/MyDrive/BCSpratyush'
nii_files = [f for f in os.listdir(nii_folder) if f.endswith('.nii') or f.endswith('.nii.gz')]

for file in nii_files:
    file_path = os.path.join(nii_folder, file)
    img = nib.load(file_path)

    print(f"=== {file} ===")
    print("Shape:", img.shape)
    print("Affine matrix:\n", img.affine)
    print("Voxel spacing (zooms):", img.header.get_zooms())
    print("Data type:", img.get_data_dtype())
    print("Header info:\n", img.header)
    print("\n\n")
# Out:
# === sub-65304_ses-1_acq-t1csmp2ragesag06mmUNIDEN_T1w.nii ===
# Shape: (256, 384, 384)
# Affine matrix:
#  [[ 6.26228750e-01 -5.86845390e-02 -3.49271894e-02 -6.36599960e+01]
#  [ 6.13057874e-02  6.20829523e-01  3.86882909e-02 -1.04477142e+02]
#  [ 3.13100182e-02 -4.18554321e-02  6.22822821e-01 -1.21944519e+02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# Voxel spacing (zooms): (np.float32(0.63), np.float32(0.625), np.float32(0.625))
# Data type: int16
# Header info:
#  <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 0
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 54
# dim             : [  3 256 384 384   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [1.    0.63  0.625 0.625 6.    0.    0.    0.   ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'TE=2.1;Time=154943.340;phase=1')
# aux_file        : np.bytes_(b'Denoised Image (lambda ')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : -0.0322827
# quatern_c       : -0.026448894
# quatern_d       : 0.04789823
# qoffset_x       : -63.659996
# qoffset_y       : -104.47714
# qoffset_z       : -121.94452
# srow_x          : [ 6.2622875e-01 -5.8684539e-02 -3.4927189e-02 -6.3659996e+01]
# srow_y          : [ 6.1305787e-02  6.2082952e-01  3.8688291e-02 -1.0447714e+02]
# srow_z          : [ 3.1310018e-02 -4.1855432e-02  6.2282282e-01 -1.2194452e+02]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
#
#
#
# === sub-66287_ses-1_acq-t1csmp2ragesag06mmUNIDEN_T1w.nii ===
# Shape: (256, 362, 384)
# Affine matrix:
#  [[ 6.29310429e-01 -1.75750051e-02  2.34336480e-02 -8.61196060e+01]
#  [ 1.57038774e-02  6.22644782e-01  5.19210324e-02 -1.00461945e+02]
#  [-2.50039119e-02 -5.12798578e-02  6.22398615e-01 -1.37777328e+02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# Voxel spacing (zooms): (np.float32(0.63), np.float32(0.625), np.float32(0.625))
# Data type: int16
# Header info:
#  <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 0
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 54
# dim             : [  3 256 362 384   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [1.    0.63  0.625 0.625 6.    0.    0.    0.   ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'TE=2.1;Time=131205.108;phase=1')
# aux_file        : np.bytes_(b'Denoised Image (lambda ')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : -0.041327026
# quatern_c       : 0.01931742
# quatern_d       : 0.0132766655
# qoffset_x       : -86.119606
# qoffset_y       : -100.461945
# qoffset_z       : -137.77733
# srow_x          : [ 6.2931043e-01 -1.7575005e-02  2.3433648e-02 -8.6119606e+01]
# srow_y          : [ 1.57038774e-02  6.22644782e-01  5.19210324e-02 -1.00461945e+02]
# srow_z          : [-2.5003912e-02 -5.1279858e-02  6.2239861e-01 -1.3777733e+02]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
#
#
#
# === sub-68576_ses-2_acq-t1csmp2ragesag06mmUNIDEN_T1w.nii ===
# Shape: (256, 362, 384)
# Affine matrix:
#  [[ 6.29829526e-01 -1.45959742e-02  2.20752831e-04 -8.00369873e+01]
#  [ 1.45067181e-02  6.17520332e-01  9.53230858e-02 -1.08615631e+02]
#  [-2.46380339e-03 -9.52919945e-02  6.17688000e-01 -1.26306412e+02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# Voxel spacing (zooms): (np.float32(0.63), np.float32(0.625), np.float32(0.625))
# Data type: int16
# Header info:
#  <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 0
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 54
# dim             : [  3 256 362 384   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [1.    0.63  0.625 0.625 6.    0.    0.    0.   ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'TE=2.1;Time=150434.397;phase=1')
# aux_file        : np.bytes_(b'Denoised Image (lambda ')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : -0.07647522
# quatern_c       : 0.0010692031
# quatern_d       : 0.0116298655
# qoffset_x       : -80.03699
# qoffset_y       : -108.61563
# qoffset_z       : -126.30641
# srow_x          : [ 6.2982953e-01 -1.4595974e-02  2.2075283e-04 -8.0036987e+01]
# srow_y          : [ 1.4506718e-02  6.1752033e-01  9.5323086e-02 -1.0861563e+02]
# srow_z          : [-2.4638034e-03 -9.5291995e-02  6.1768800e-01 -1.2630641e+02]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
#
#
#
# === sub-65304_ses-2_acq-t1csmp2ragesag06mmUNIDEN_T1w.nii ===
# Shape: (256, 384, 384)
# Affine matrix:
#  [[ 6.29997253e-01  5.55168139e-04  1.25112594e-03 -8.05287628e+01]
#  [-6.74987154e-04  6.22265875e-01  5.83925396e-02 -1.00282349e+02]
#  [-1.20333256e-03 -5.83937392e-02  6.22264981e-01 -1.19656151e+02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# Voxel spacing (zooms): (np.float32(0.63), np.float32(0.625), np.float32(0.625))
# Data type: int16
# Header info:
#  <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 0
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 54
# dim             : [  3 256 384 384   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [1.    0.63  0.625 0.625 6.    0.    0.    0.   ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'TE=2.1;Time=160652.807;phase=1')
# aux_file        : np.bytes_(b'Denoised Image (lambda ')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : -0.04676571
# quatern_c       : 0.000979036
# quatern_d       : -0.00049045676
# qoffset_x       : -80.52876
# qoffset_y       : -100.28235
# qoffset_z       : -119.65615
# srow_x          : [ 6.2999725e-01  5.5516814e-04  1.2511259e-03 -8.0528763e+01]
# srow_y          : [-6.7498715e-04  6.2226588e-01  5.8392540e-02 -1.0028235e+02]
# srow_z          : [-1.2033326e-03 -5.8393739e-02  6.2226498e-01 -1.1965615e+02]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
#
#
#
# === sub-62038_ses-1_acq-t1csmp2ragesag06mmUNIDEN_T1w.nii ===
# Shape: (256, 362, 384)
# Affine matrix:
#  [[ 6.29074156e-01 -1.33072212e-02 -3.11387163e-02 -7.36054077e+01]
#  [ 1.63442213e-02  6.21981978e-01  5.91654330e-02 -1.00073349e+02]
#  [ 2.99664345e-02 -5.98863661e-02  6.21413589e-01 -1.19990189e+02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]]
# Voxel spacing (zooms): (np.float32(0.63), np.float32(0.625), np.float32(0.625))
# Data type: int16
# Header info:
#  <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 0
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 54
# dim             : [  3 256 362 384   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [1.    0.63  0.625 0.625 6.    0.    0.    0.   ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'TE=2.1;Time=132725.145;phase=1')
# aux_file        : np.bytes_(b'Denoised Image (lambda ')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : -0.047692526
# quatern_c       : -0.02438365
# quatern_d       : 0.011826501
# qoffset_x       : -73.60541
# qoffset_y       : -100.07335
# qoffset_z       : -119.99019
# srow_x          : [ 6.2907416e-01 -1.3307221e-02 -3.1138716e-02 -7.3605408e+01]
# srow_y          : [ 1.6344221e-02  6.2198198e-01  5.9165433e-02 -1.0007335e+02]
# srow_z          : [ 2.9966434e-02 -5.9886366e-02  6.2141359e-01 -1.1999019e+02]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')

# %%
# !pip install pydicom numpy
# Out:
# Collecting pydicom
#   Downloading pydicom-3.0.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Downloading pydicom-3.0.1-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 29.3 MB/s eta 0:00:00
# Installing collected packages: pydicom
# Successfully installed pydicom-3.0.1

# %%
import os
import numpy as np
import pydicom

def get_sort_key(dicom_header_ds):
    """
    Given a pydicom Dataset loaded with `stop_before_pixels=True`,
    return a numeric key for sorting:
      1) If InstanceNumber exists and is not None, return int(InstanceNumber).
      2) Else if ImagePositionPatient exists, return its z-component (float).
      3) Otherwise return 0.
    """
    inst = getattr(dicom_header_ds, "InstanceNumber", None)
    if inst is not None:
        try:
            return int(inst)
        except:
            pass

    ipp = getattr(dicom_header_ds, "ImagePositionPatient", None)
    if isinstance(ipp, (list, tuple)) and len(ipp) == 3:
        try:
            return float(ipp[2])
        except:
            pass

    return 0


def load_and_sort_dicom_filepaths(dicom_folder):
    """
    1. Read only the headers of all .dcm files in `dicom_folder` to compute sort keys.
    2. Return a list of full file paths sorted by InstanceNumber (if available) or ImagePositionPatient[2].
    """
    # Step 1: Gather all .dcm paths
    dicom_paths = [
        os.path.join(dicom_folder, fname)
        for fname in os.listdir(dicom_folder)
        if fname.lower().endswith(".dcm")
    ]
    if not dicom_paths:
        raise FileNotFoundError(f"No DICOM files (.dcm) found in folder: {dicom_folder}")

    # Step 2: Read headers only to build (path, sort_key) pairs
    path_key_pairs = []
    for fpath in dicom_paths:
        try:
            ds_header = pydicom.dcmread(fpath, stop_before_pixels=True)
        except Exception as e:
            # Skip unreadable headers
            print(f"  WARNING: Cannot read header of {fpath!r} → {e}")
            continue
        key = get_sort_key(ds_header)
        path_key_pairs.append((fpath, key))

    if not path_key_pairs:
        raise RuntimeError(f"No valid DICOM headers could be read in: {dicom_folder}")

    # Step 3: Sort pairs by key ascending
    path_key_pairs.sort(key=lambda pk: pk[1])

    # Step 4: Extract sorted file paths
    sorted_paths = [pk[0] for pk in path_key_pairs]
    return sorted_paths


def stack_dicom_series_to_volume(dicom_folder):
    """
    1. Calls `load_and_sort_dicom_filepaths(dicom_folder)` to get sorted file paths.
    2. Iterates over sorted file paths, fully reads each DICOM (with pixel data),
       and stacks the 2D pixel_array into a 3D NumPy array of shape (num_slices, rows, cols).
    3. Extracts voxel spacing from the first slice’s metadata.

    Returns:
      - volume_3d: NumPy array of shape (num_slices, rows, cols)
      - voxel_spacing: tuple (row_spacing_mm, col_spacing_mm, slice_spacing_mm)
    """
    # Step A: Get sorted list of file paths
    sorted_filepaths = load_and_sort_dicom_filepaths(dicom_folder)

    # Step B: Read the first slice fully (with pixel data) to get shape & dtype
    first_ds_full = pydicom.dcmread(sorted_filepaths[0])
    first_slice_array = first_ds_full.pixel_array
    rows, cols = first_slice_array.shape
    dtype = first_slice_array.dtype
    n_slices = len(sorted_filepaths)

    # Step C: Pre-allocate volume
    volume_3d = np.zeros((n_slices, rows, cols), dtype=dtype)

    # Step D: Fill the 3D volume
    for i, fpath in enumerate(sorted_filepaths):
        ds_full = pydicom.dcmread(fpath)   # read with pixel data
        arr = ds_full.pixel_array
        if arr.shape != (rows, cols):
            raise RuntimeError(
                f"Shape mismatch: slice {i} from file {fpath} has shape {arr.shape}, "
                f"expected {(rows, cols)}"
            )
        volume_3d[i, :, :] = arr

    # Step E: Extract voxel spacing from first slice
    ps = first_ds_full.get("PixelSpacing", [None, None])
    row_spacing = float(ps[0]) if ps[0] is not None else None
    col_spacing = float(ps[1]) if ps[1] is not None else None

    slice_thickness = first_ds_full.get("SliceThickness", None)
    spacing_between = first_ds_full.get("SpacingBetweenSlices", None)
    if spacing_between is not None:
        slice_spacing = float(spacing_between)
    elif slice_thickness is not None:
        slice_spacing = float(slice_thickness)
    else:
        slice_spacing = None

    voxel_spacing = (row_spacing, col_spacing, slice_spacing)

    return volume_3d, voxel_spacing

# --------------------------------------------------
# Example usage: Replace with your actual folder path
# --------------------------------------------------

dicom_folder_path = "/content/drive/MyDrive/BCSpratyush2/sub-62038_ses-1_acq-t1csmp2ragesag06mmUNIDEN_T1w"

print(f"Reading and sorting DICOM slices in: {dicom_folder_path}")
dicom_volume, dicom_voxel_spacing = stack_dicom_series_to_volume(dicom_folder_path)

print("\n[DICOM] Finished stacking:")
print(f"  Volume shape (slices, rows, cols): {dicom_volume.shape}")
print(f"  Voxel spacing (row_mm, col_mm, slice_mm): {dicom_voxel_spacing}")
# Out:
# Reading and sorting DICOM slices in: /content/drive/MyDrive/BCSpratyush2/sub-62038_ses-1_acq-t1csmp2ragesag06mmUNIDEN_T1w
#
# [DICOM] Finished stacking:
#   Volume shape (slices, rows, cols): (384, 362, 256)
#   Voxel spacing (row_mm, col_mm, slice_mm): (0.625, 0.629999995231628, 1.0)

# %%
import os
import numpy as np
import pydicom

dicom_folder = '/content/drive/MyDrive/BCSpratyush2'

# Get all .dcm files
dicom_files = [os.path.join(dicom_folder, f) for f in os.listdir(dicom_folder) if f.lower().endswith('.dcm')]
print(f"Number of DICOM files found: {len(dicom_files)}")

# Read slices
slices = [pydicom.dcmread(f) for f in dicom_files]
print(f"Number of slices successfully read: {len(slices)}")

# Verify pixel arrays
valid_slices = []
for i, s in enumerate(slices):
    try:
        _ = s.pixel_array
        valid_slices.append(s)
    except Exception as e:
        print(f"Slice {i} skipped (no pixel_array): {e}")

print(f"Number of valid image slices: {len(valid_slices)}")

# Proceed only if we have valid image slices
if valid_slices:
    # Sort slices by ImagePositionPatient or InstanceNumber
    valid_slices.sort(key=lambda s: float(s.ImagePositionPatient[2]) if 'ImagePositionPatient' in s else int(s.InstanceNumber))

    # Stack pixel arrays into a 3D volume
    volume = np.stack([s.pixel_array for s in valid_slices], axis=-1)
    print("Stacked volume shape:", volume.shape)

    # Example: Extract metadata from the first slice
    sample = valid_slices[0]
    print("Patient Name:", sample.PatientName)
    print("Modality:", sample.Modality)
    print("Pixel Spacing:", sample.PixelSpacing)
    print("Slice Thickness:", sample.SliceThickness)
    print("Image Position Patient:", sample.ImagePositionPatient)
else:
    print("No valid image slices found.")
# Out:
# Number of DICOM files found: 0
# Number of slices successfully read: 0
# Number of valid image slices: 0
# No valid image slices found.

# %%
import matplotlib.pyplot as plt

def show_slices(slices, title):
    fig, axes = plt.subplots(1, len(slices), figsize=(12, 5))
    for i, slice in enumerate(slices):
        axes[i].imshow(slice.T, cmap="gray", origin="lower")
        axes[i].axis('off')
    fig.suptitle(title)
    plt.show()

# Visualizing from NIfTI file
img = nib.load(nii_path)
data = img.get_fdata()

# Axial, Coronal, Sagittal slices
axial_slice = data[:, :, data.shape[2]//2]
coronal_slice = data[:, data.shape[1]//2, :]
sagittal_slice = data[data.shape[0]//2, :, :]

show_slices([axial_slice, coronal_slice, sagittal_slice], "Anatomical Planes: Axial | Coronal | Sagittal")
